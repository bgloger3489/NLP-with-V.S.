# %%
import numpy as np
import pandas as pd
import pandas_dedupe
import matplotlib.pyplot as plt
import spacy
import json
import re
import tqdm

nlp = spacy.load("en_core_web_lg")

articles = []
for line in open('/Users/Ben/Desktop/Vital Strategies/Prodigy dump/Vital_Feeds_Dump_7_16_2019/Heat_Not_Burn_search_result_2019-07-16_04_07_31.940459.jsonl'):
    articles.append(json.loads(line)["_source"])
print('Loaded {} docs'.format(len(articles)))
# Out:
# Loaded 1774 docs

# %%
data = pd.DataFrame(articles)
data = pandas_dedupe.dedupe_dataframe(data,["title","date","author","full_domain_name"])
# Out:
# importing data ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c2fba673ba19> in <module>()
#       1 data = pd.DataFrame(articles)
# ----> 2 data = pandas_dedupe.dedupe_dataframe(data,["title","date","author","full_domain_name"])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas_dedupe/dedupe_dataframe.py in dedupe_dataframe(df, field_properties, canonicalize, config_name)
#      49
#      50         # To train dedupe, we feed it a sample of records.
# ---> 51         deduper.sample(data_d, 15000)
#      52
#      53         # If we have training data saved from a previous run of dedupe,
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/api.py in sample(self, data, sample_size, blocked_proportion, original_length)
#     795                                                  blocked_proportion,
#     796                                                  sample_size,
# --> 797                                                  original_length)
#     798
#     799     def _checkData(self, data):
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/labeler.py in __init__(self, data_model, data, blocked_proportion, sample_size, original_length)
#     394                                           self.candidates,
#     395                                           data,
# --> 396                                           original_length)
#     397
#     398         self._common_init()
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/labeler.py in __init__(self, data_model, candidates, data, original_length)
#     240         self.block_learner = training.DedupeBlockLearner(preds,
#     241                                                          sampled_records,
# --> 242                                                          index_data)
#     243
#     244         self._index_predicates(self.candidates)
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/training.py in __init__(self, predicates, sampled_records, data)
#     126         compound_predicates = self.compound(simple_cover, compound_length)
#     127         self.comparison_count = self.comparisons(compound_predicates,
# --> 128                                                  simple_cover)
#     129
#     130     @staticmethod
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/training.py in comparisons(self, predicates, simple_cover)
#      79         for pred in predicates:
#      80             if len(pred) > 1:
# ---> 81                 estimate = self.estimate(compounder(pred))
#      82             else:
#      83                 estimate = self.estimate(simple_cover[pred])
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/training.py in __call__(self, compound_predicate)
#     106                 a_cover = self.cover[a]
#     107
# --> 108             return a_cover * self.cover[b]
#     109
#     110
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/training.py in __mul__(self, other)
#     378
#     379         common = {k: v * larger[k]
# --> 380                   for k, v in viewitems(smaller)
#     381                   if k in larger_keys}
#     382
#
# ~/anaconda3/lib/python3.6/site-packages/dedupe/training.py in <dictcomp>(.0)
#     379         common = {k: v * larger[k]
#     380                   for k, v in viewitems(smaller)
# --> 381                   if k in larger_keys}
#     382
#     383         return Counter(common)
#
# KeyboardInterrupt:

# %%
#canonicalize on relavant coulumns
#pd.drop_duplicates on subset of columns
#save file

# %%
#NEED TO DO SYNONYM CONFLATION

# %% [markdown]
# # try with a minimal threshold at the document level

# %%
#DOCUMENT LEVEL

harm_reduction_keywords = ["harm", "reduce", "alternative", "safe", "healthy", "help", "quit", "switch"]
#ensure keywords are in fact properly lemmanized
for i in range(len(harm_reduction_keywords)):
    harm_reduction_keywords[i] = nlp(harm_reduction_keywords[i])[0].lemma_.lower()
    
    
count_by_date = {} #{"MM/YYYY":[PMI related docs, JUUL related docs, IQOS related docs, Total docs written] } 
                    #counts the references to harm reduction with resepect to PMI, IQOS, JUUL
PMI = 0
JUUL = 1
IQOS = 2
TOTAL_DOCS = 3

#populate 
for year in range(1990,2020):
    for month in range(1,13):
        for day in range(1,32):
            
            if((month == 4 or month == 6 or month == 9 or month == 11) and day == 31 or (month == 2 and day > 28)):
                break
            
            date = str(year)+"-"
            if month < 10:
                date += "0"
            date += str(month)+"-"
            if day < 10:
                date += "0"
            date += str(day)
            count_by_date[date] = [0,0,0,0]
            
            
def format_date(string):
    return string[:10]


aliases_list = [
    ["pmi", "philip morris", "calantzopoulos"],
    ["juul", "burns"],
    ["iqos"]
]

def check_aliases(COMPANY, ents):
    for ent in ents:
        if ent.text.lower() in aliases_list[COMPANY]:
            return True
    return False

THRESHOLD = .75
#iterate through the documents
for article in tqdm.tqdm_notebook(articles):
    date = format_date(article["date"])
    count_by_date[date][TOTAL_DOCS] += 1
    
    #1. check for pro-industry
    if article["max_ten_sent_prob_avg"] > THRESHOLD:
        doc = nlp(article["text"])
        
        #2. check for harm reduction keyword
        for word in doc:
            if word.lemma_.lower() in harm_reduction_keywords:
                
                #3. check for PMI, JUUL, IQOS
                if check_aliases(PMI,doc.ents):
                    count_by_date[date][PMI] +=1
                if check_aliases(JUUL,doc.ents):
                    count_by_date[date][JUUL] +=1
                if check_aliases(IQOS,doc.ents):                
                    count_by_date[date][IQOS] +=1
                
                break
# Out:
# HBox(children=(IntProgress(value=0, max=1774), HTML(value='')))

# %%
data = np.asarray(list(count_by_date.items()))

PMI_harm_reduction = [item[PMI] for item in data[:,1]]
JUUL_harm_reduction = [item[JUUL] for item in data[:,1]]
IQOS_harm_reduction = [item[IQOS] for item in data[:,1]]
dates = list(count_by_date.keys())
years = [year[:4] for year in list(count_by_date.keys())[::12]]

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(len(PMI_harm_reduction)), PMI_harm_reduction,label="PMI")
plt.plot(range(len(PMI_harm_reduction)), JUUL_harm_reduction,label="JUUL")
plt.plot(range(len(PMI_harm_reduction)), IQOS_harm_reduction,label="IQOS")
plt.title("Harm Reduction Related Articles Over Time")
plt.xlabel("Time")
plt.xticks(range(len(data))[::500], data[::500,0], rotation=300)
plt.ylabel("Number of Related Docs")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(len(PMI_harm_reduction))[12*26*31:], PMI_harm_reduction[12*26*31:],label="PMI")
plt.plot(range(len(PMI_harm_reduction))[12*26*31:], JUUL_harm_reduction[12*26*31:],label="JUUL")
plt.plot(range(len(PMI_harm_reduction))[12*26*31:], IQOS_harm_reduction[12*26*31:],label="IQOS")
plt.title("Harm Reduction Related Articles Over Time")
plt.xlabel("Time")
plt.xticks(range(len(data))[12*26*31::80],data[12*26*31::80,0], rotation=300)
plt.ylabel("Number of Related Docs")
plt.legend()
plt.show()

# %%
list(data)[12*26*31:]
# Out:
# [array(['2016-07-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-09', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-07-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-19', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-07-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-27', list([0, 0, 1, 1])], dtype=object),
#  array(['2016-07-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-07-31', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-12', list([0, 0, 0, 3])], dtype=object),
#  array(['2016-08-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-08-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-08-31', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-22', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-09-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-25', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-09-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-28', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-09-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-09-30', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-10-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-05', list([1, 0, 1, 1])], dtype=object),
#  array(['2016-10-06', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-10-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-10', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-10-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-19', list([0, 0, 0, 2])], dtype=object),
#  array(['2016-10-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-24', list([2, 0, 2, 2])], dtype=object),
#  array(['2016-10-25', list([1, 0, 1, 3])], dtype=object),
#  array(['2016-10-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-10-31', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-01', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-11-02', list([1, 0, 1, 1])], dtype=object),
#  array(['2016-11-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-08', list([2, 0, 0, 2])], dtype=object),
#  array(['2016-11-09', list([1, 1, 0, 1])], dtype=object),
#  array(['2016-11-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-11', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-11-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-11-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-18', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-11-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-11-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-26', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-11-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-11-30', list([8, 0, 7, 16])], dtype=object),
#  array(['2016-12-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-06', list([0, 0, 0, 2])], dtype=object),
#  array(['2016-12-07', list([1, 0, 1, 1])], dtype=object),
#  array(['2016-12-08', list([0, 0, 0, 2])], dtype=object),
#  array(['2016-12-09', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-12-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-13', list([1, 0, 0, 1])], dtype=object),
#  array(['2016-12-14', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-12-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-12-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2016-12-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2016-12-31', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-05', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-01-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-07', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-09', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-01-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-13', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-17', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-18', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-21', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-24', list([1, 0, 0, 3])], dtype=object),
#  array(['2017-01-25', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-01-30', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-01-31', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-02-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-03', list([1, 0, 0, 2])], dtype=object),
#  array(['2017-02-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-06', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-02-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-08', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-02-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-10', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-02-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-13', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-02-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-23', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-02-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-02-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-02', list([3, 0, 0, 4])], dtype=object),
#  array(['2017-03-03', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-03-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-08', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-03-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-10', list([2, 0, 0, 2])], dtype=object),
#  array(['2017-03-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-15', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-03-16', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-03-17', list([3, 0, 3, 5])], dtype=object),
#  array(['2017-03-18', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-03-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-21', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-03-22', list([0, 0, 0, 4])], dtype=object),
#  array(['2017-03-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-27', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-03-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-03-29', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-03-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-03-31', list([0, 0, 0, 5])], dtype=object),
#  array(['2017-04-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-03', list([1, 0, 1, 4])], dtype=object),
#  array(['2017-04-04', list([2, 0, 1, 2])], dtype=object),
#  array(['2017-04-05', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-04-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-09', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-04-10', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-04-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-04-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-19', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-04-20', list([2, 0, 2, 2])], dtype=object),
#  array(['2017-04-21', list([3, 0, 3, 3])], dtype=object),
#  array(['2017-04-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-04-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-04-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-04-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-03', list([0, 0, 0, 5])], dtype=object),
#  array(['2017-05-04', list([1, 0, 0, 2])], dtype=object),
#  array(['2017-05-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-08', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-05-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-05-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-15', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-05-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-17', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-05-18', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-05-19', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-05-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-22', list([2, 0, 2, 2])], dtype=object),
#  array(['2017-05-23', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-05-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-25', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-05-26', list([1, 0, 4, 6])], dtype=object),
#  array(['2017-05-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-05-29', list([3, 0, 3, 3])], dtype=object),
#  array(['2017-05-30', list([6, 0, 2, 7])], dtype=object),
#  array(['2017-05-31', list([1, 0, 0, 2])], dtype=object),
#  array(['2017-06-01', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-05', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-09', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-06-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-12', list([2, 0, 0, 2])], dtype=object),
#  array(['2017-06-13', list([1, 0, 0, 3])], dtype=object),
#  array(['2017-06-14', list([1, 0, 0, 2])], dtype=object),
#  array(['2017-06-15', list([2, 0, 1, 3])], dtype=object),
#  array(['2017-06-16', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-06-17', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-19', list([2, 0, 0, 2])], dtype=object),
#  array(['2017-06-20', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-21', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-22', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-06-25', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-06-27', list([2, 0, 2, 2])], dtype=object),
#  array(['2017-06-28', list([4, 0, 2, 11])], dtype=object),
#  array(['2017-06-29', list([2, 0, 1, 3])], dtype=object),
#  array(['2017-06-30', list([7, 0, 7, 8])], dtype=object),
#  array(['2017-07-01', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-07-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-03', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-07-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-05', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-07-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-07', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-07-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-10', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-07-11', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-07-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-13', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-07-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-17', list([1, 0, 1, 5])], dtype=object),
#  array(['2017-07-18', list([2, 0, 0, 2])], dtype=object),
#  array(['2017-07-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-20', list([4, 0, 3, 6])], dtype=object),
#  array(['2017-07-21', list([2, 0, 2, 2])], dtype=object),
#  array(['2017-07-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-07-24', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-07-25', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-07-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-27', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-07-28', list([4, 0, 1, 12])], dtype=object),
#  array(['2017-07-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-07-31', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-08-01', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-08-02', list([1, 0, 1, 7])], dtype=object),
#  array(['2017-08-03', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-08-04', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-08-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-08', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-08-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-10', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-08-11', list([1, 0, 1, 3])], dtype=object),
#  array(['2017-08-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-08-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-14', list([1, 0, 1, 3])], dtype=object),
#  array(['2017-08-15', list([3, 0, 3, 3])], dtype=object),
#  array(['2017-08-16', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-08-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-18', list([0, 0, 1, 2])], dtype=object),
#  array(['2017-08-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-21', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-08-22', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-08-23', list([0, 0, 1, 3])], dtype=object),
#  array(['2017-08-24', list([1, 0, 1, 3])], dtype=object),
#  array(['2017-08-25', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-08-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-08-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-08-29', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-08-30', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-08-31', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-09-01', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-09-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-05', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-09-06', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-09-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-08', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-09-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-09-13', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-09-14', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-09-15', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-09-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-09-17', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-09-18', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-09-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-20', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-09-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-22', list([1, 0, 0, 2])], dtype=object),
#  array(['2017-09-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-09-27', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-09-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-09-29', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-09-30', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-10-01', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-10-02', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-10-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-11', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-10-12', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-10-13', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-10-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-16', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-10-17', list([1, 0, 0, 3])], dtype=object),
#  array(['2017-10-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-19', list([3, 0, 3, 6])], dtype=object),
#  array(['2017-10-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-22', list([2, 0, 2, 2])], dtype=object),
#  array(['2017-10-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-24', list([0, 0, 1, 1])], dtype=object),
#  array(['2017-10-25', list([3, 0, 0, 7])], dtype=object),
#  array(['2017-10-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-10-27', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-10-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-10-29', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-10-30', list([3, 0, 1, 3])], dtype=object),
#  array(['2017-10-31', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-11-01', list([1, 0, 1, 5])], dtype=object),
#  array(['2017-11-02', list([1, 0, 2, 5])], dtype=object),
#  array(['2017-11-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-04', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-11-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-07', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-11-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-09', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-11-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-11', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-11-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-14', list([1, 0, 0, 8])], dtype=object),
#  array(['2017-11-15', list([2, 0, 1, 2])], dtype=object),
#  array(['2017-11-16', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-11-17', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-11-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-19', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-11-20', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-11-21', list([2, 0, 2, 7])], dtype=object),
#  array(['2017-11-22', list([1, 0, 1, 2])], dtype=object),
#  array(['2017-11-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-11-24', list([2, 0, 3, 3])], dtype=object),
#  array(['2017-11-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-11-27', list([0, 0, 0, 2])], dtype=object),
#  array(['2017-11-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-11-29', list([2, 0, 2, 2])], dtype=object),
#  array(['2017-11-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-01', list([0, 0, 0, 3])], dtype=object),
#  array(['2017-12-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-03', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-12-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-09', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-12-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-11', list([0, 0, 0, 4])], dtype=object),
#  array(['2017-12-12', list([2, 0, 2, 7])], dtype=object),
#  array(['2017-12-13', list([0, 0, 2, 3])], dtype=object),
#  array(['2017-12-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-15', list([0, 0, 1, 1])], dtype=object),
#  array(['2017-12-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-17', list([1, 0, 0, 1])], dtype=object),
#  array(['2017-12-18', list([1, 0, 1, 4])], dtype=object),
#  array(['2017-12-19', list([2, 0, 3, 5])], dtype=object),
#  array(['2017-12-20', list([6, 0, 5, 13])], dtype=object),
#  array(['2017-12-21', list([4, 0, 4, 5])], dtype=object),
#  array(['2017-12-22', list([2, 1, 0, 5])], dtype=object),
#  array(['2017-12-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-24', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-12-25', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-12-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2017-12-27', list([1, 1, 0, 2])], dtype=object),
#  array(['2017-12-28', list([2, 0, 0, 2])], dtype=object),
#  array(['2017-12-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2017-12-30', list([1, 0, 1, 1])], dtype=object),
#  array(['2017-12-31', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-01-01', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-01-02', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-01-03', list([1, 0, 0, 3])], dtype=object),
#  array(['2018-01-04', list([1, 0, 0, 8])], dtype=object),
#  array(['2018-01-05', list([2, 0, 2, 6])], dtype=object),
#  array(['2018-01-06', list([1, 0, 1, 5])], dtype=object),
#  array(['2018-01-07', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-01-08', list([3, 0, 3, 3])], dtype=object),
#  array(['2018-01-09', list([4, 0, 4, 4])], dtype=object),
#  array(['2018-01-10', list([0, 0, 0, 7])], dtype=object),
#  array(['2018-01-11', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-01-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-01-13', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-01-14', list([0, 0, 1, 2])], dtype=object),
#  array(['2018-01-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-01-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-01-17', list([1, 0, 1, 6])], dtype=object),
#  array(['2018-01-18', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-01-19', list([27, 0, 0, 27])], dtype=object),
#  array(['2018-01-20', list([3, 0, 1, 3])], dtype=object),
#  array(['2018-01-21', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-01-22', list([31, 0, 2, 38])], dtype=object),
#  array(['2018-01-23', list([3, 0, 0, 3])], dtype=object),
#  array(['2018-01-24', list([8, 0, 1, 10])], dtype=object),
#  array(['2018-01-25', list([32, 0, 11, 63])], dtype=object),
#  array(['2018-01-26', list([8, 0, 5, 12])], dtype=object),
#  array(['2018-01-27', list([2, 0, 1, 4])], dtype=object),
#  array(['2018-01-28', list([2, 0, 0, 4])], dtype=object),
#  array(['2018-01-29', list([6, 0, 4, 6])], dtype=object),
#  array(['2018-01-30', list([3, 0, 3, 9])], dtype=object),
#  array(['2018-01-31', list([2, 1, 1, 4])], dtype=object),
#  array(['2018-02-01', list([0, 0, 0, 8])], dtype=object),
#  array(['2018-02-02', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-02-03', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-02-04', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-02-05', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-02-06', list([5, 1, 5, 10])], dtype=object),
#  array(['2018-02-07', list([10, 0, 10, 14])], dtype=object),
#  array(['2018-02-08', list([4, 0, 4, 6])], dtype=object),
#  array(['2018-02-09', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-02-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-11', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-02-12', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-02-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-15', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-02-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-17', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-02-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-20', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-02-21', list([2, 0, 0, 10])], dtype=object),
#  array(['2018-02-22', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-02-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-02-24', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-02-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-02-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-02-27', list([2, 0, 2, 3])], dtype=object),
#  array(['2018-02-28', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-03-01', list([2, 0, 2, 2])], dtype=object),
#  array(['2018-03-02', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-03-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-04', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-03-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-06', list([0, 0, 0, 5])], dtype=object),
#  array(['2018-03-07', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-03-08', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-03-09', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-03-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-03-13', list([2, 0, 0, 3])], dtype=object),
#  array(['2018-03-14', list([0, 0, 0, 4])], dtype=object),
#  array(['2018-03-15', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-03-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-03-17', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-03-18', list([0, 0, 1, 1])], dtype=object),
#  array(['2018-03-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-20', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-03-21', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-03-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-23', list([2, 0, 0, 4])], dtype=object),
#  array(['2018-03-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-27', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-03-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-03-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-03-30', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-03-31', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-04-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-02', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-04-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-06', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-04-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-09', list([1, 0, 0, 3])], dtype=object),
#  array(['2018-04-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-11', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-04-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-16', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-04-17', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-04-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-19', list([2, 0, 2, 9])], dtype=object),
#  array(['2018-04-20', list([4, 0, 4, 11])], dtype=object),
#  array(['2018-04-21', list([0, 0, 0, 4])], dtype=object),
#  array(['2018-04-22', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-04-23', list([3, 0, 2, 4])], dtype=object),
#  array(['2018-04-24', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-04-25', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-04-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-27', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-04-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-04-30', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-05-01', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-05-02', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-05-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-07', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-05-08', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-05-09', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-05-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-05-13', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-05-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-15', list([4, 0, 0, 9])], dtype=object),
#  array(['2018-05-16', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-05-17', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-05-18', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-05-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-21', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-05-22', list([1, 1, 1, 1])], dtype=object),
#  array(['2018-05-23', list([0, 0, 1, 1])], dtype=object),
#  array(['2018-05-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-05-30', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-05-31', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-06-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-04', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-06-05', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-06-06', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-06-07', list([3, 0, 0, 4])], dtype=object),
#  array(['2018-06-08', list([4, 0, 0, 5])], dtype=object),
#  array(['2018-06-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-11', list([2, 0, 1, 3])], dtype=object),
#  array(['2018-06-12', list([0, 0, 0, 4])], dtype=object),
#  array(['2018-06-13', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-06-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-15', list([5, 0, 5, 5])], dtype=object),
#  array(['2018-06-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-17', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-06-18', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-06-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-20', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-21', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-06-22', list([2, 1, 0, 3])], dtype=object),
#  array(['2018-06-23', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-06-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-25', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-06-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-27', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-06-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-06-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-01', list([0, 0, 1, 1])], dtype=object),
#  array(['2018-07-02', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-04', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-07-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-06', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-10', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-15', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-07-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-17', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-07-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-19', list([2, 0, 2, 7])], dtype=object),
#  array(['2018-07-20', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-22', list([1, 1, 1, 3])], dtype=object),
#  array(['2018-07-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-25', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-07-26', list([3, 0, 3, 6])], dtype=object),
#  array(['2018-07-27', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-07-30', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-07-31', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-01', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-03', list([2, 0, 2, 2])], dtype=object),
#  array(['2018-08-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-05', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-06', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-08-07', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-10', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-08-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-17', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-18', list([0, 0, 2, 2])], dtype=object),
#  array(['2018-08-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-20', list([0, 0, 0, 5])], dtype=object),
#  array(['2018-08-21', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-22', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-08-23', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-08-24', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-08-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-08-27', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-08-28', list([0, 0, 0, 10])], dtype=object),
#  array(['2018-08-29', list([0, 0, 0, 9])], dtype=object),
#  array(['2018-08-30', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-08-31', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-03', list([0, 0, 0, 4])], dtype=object),
#  array(['2018-09-04', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-06', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-07', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-09-08', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-10', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-09-11', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-12', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-09-13', list([1, 1, 1, 2])], dtype=object),
#  array(['2018-09-14', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-09-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-17', list([2, 0, 1, 2])], dtype=object),
#  array(['2018-09-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-20', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-21', list([2, 0, 2, 2])], dtype=object),
#  array(['2018-09-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-25', list([0, 0, 0, 4])], dtype=object),
#  array(['2018-09-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-09-27', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-09-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-09-29', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-09-30', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-10-01', list([4, 0, 2, 5])], dtype=object),
#  array(['2018-10-02', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-10-03', list([1, 0, 1, 3])], dtype=object),
#  array(['2018-10-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-05', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-10-06', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-10-07', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-10-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-11', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-10-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-14', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-10-15', list([1, 0, 0, 3])], dtype=object),
#  array(['2018-10-16', list([0, 0, 0, 5])], dtype=object),
#  array(['2018-10-17', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-10-18', list([9, 1, 8, 11])], dtype=object),
#  array(['2018-10-19', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-10-20', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-10-21', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-10-22', list([2, 0, 2, 11])], dtype=object),
#  array(['2018-10-23', list([114, 0, 86, 121])], dtype=object),
#  array(['2018-10-24', list([2, 0, 1, 4])], dtype=object),
#  array(['2018-10-25', list([1, 0, 1, 5])], dtype=object),
#  array(['2018-10-26', list([2, 0, 2, 4])], dtype=object),
#  array(['2018-10-27', list([1, 0, 0, 1])], dtype=object),
#  array(['2018-10-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-10-30', list([0, 0, 0, 5])], dtype=object),
#  array(['2018-10-31', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-11-01', list([3, 0, 4, 6])], dtype=object),
#  array(['2018-11-02', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-11-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-05', list([1, 0, 0, 3])], dtype=object),
#  array(['2018-11-06', list([0, 0, 0, 5])], dtype=object),
#  array(['2018-11-07', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-09', list([1, 1, 1, 1])], dtype=object),
#  array(['2018-11-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-12', list([0, 0, 0, 4])], dtype=object),
#  array(['2018-11-13', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-11-14', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-15', list([1, 0, 1, 3])], dtype=object),
#  array(['2018-11-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-17', list([0, 0, 0, 6])], dtype=object),
#  array(['2018-11-18', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-11-19', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-11-20', list([1, 0, 1, 1])], dtype=object),
#  array(['2018-11-21', list([1, 0, 1, 3])], dtype=object),
#  array(['2018-11-22', list([1, 0, 1, 2])], dtype=object),
#  array(['2018-11-23', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-11-24', list([0, 0, 1, 1])], dtype=object),
#  array(['2018-11-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-26', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-11-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-11-30', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-12-01', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-12-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-03', list([1, 0, 1, 3])], dtype=object),
#  array(['2018-12-04', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-12-05', list([1, 1, 1, 1])], dtype=object),
#  array(['2018-12-06', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-12-07', list([0, 0, 0, 2])], dtype=object),
#  array(['2018-12-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-12', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-13', list([1, 1, 1, 1])], dtype=object),
#  array(['2018-12-14', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-12-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-17', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-12-18', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-19', list([1, 0, 1, 3])], dtype=object),
#  array(['2018-12-20', list([0, 0, 0, 3])], dtype=object),
#  array(['2018-12-21', list([1, 0, 0, 2])], dtype=object),
#  array(['2018-12-22', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-23', list([1, 1, 1, 2])], dtype=object),
#  array(['2018-12-24', list([1, 1, 1, 1])], dtype=object),
#  array(['2018-12-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-27', list([1, 1, 1, 1])], dtype=object),
#  array(['2018-12-28', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-12-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2018-12-30', list([0, 0, 0, 1])], dtype=object),
#  array(['2018-12-31', list([3, 3, 3, 5])], dtype=object),
#  array(['2019-01-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-02', list([2, 1, 2, 3])], dtype=object),
#  array(['2019-01-03', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-04', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-06', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-07', list([1, 0, 1, 2])], dtype=object),
#  array(['2019-01-08', list([0, 0, 0, 2])], dtype=object),
#  array(['2019-01-09', list([0, 0, 0, 2])], dtype=object),
#  array(['2019-01-10', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-11', list([1, 0, 0, 1])], dtype=object),
#  array(['2019-01-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-14', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-15', list([1, 1, 1, 1])], dtype=object),
#  array(['2019-01-16', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-17', list([1, 0, 2, 3])], dtype=object),
#  array(['2019-01-18', list([0, 0, 1, 2])], dtype=object),
#  array(['2019-01-19', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-20', list([1, 0, 1, 1])], dtype=object),
#  array(['2019-01-21', list([2, 0, 11, 22])], dtype=object),
#  array(['2019-01-22', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-01-23', list([0, 0, 0, 4])], dtype=object),
#  array(['2019-01-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-29', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-30', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-01-31', list([0, 0, 0, 6])], dtype=object),
#  array(['2019-02-01', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-03', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-02-04', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-06', list([0, 0, 0, 2])], dtype=object),
#  array(['2019-02-07', list([4, 0, 4, 5])], dtype=object),
#  array(['2019-02-08', list([0, 1, 3, 4])], dtype=object),
#  array(['2019-02-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-11', list([0, 0, 1, 7])], dtype=object),
#  array(['2019-02-12', list([0, 0, 1, 4])], dtype=object),
#  array(['2019-02-13', list([0, 0, 0, 3])], dtype=object),
#  array(['2019-02-14', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-02-15', list([0, 0, 0, 2])], dtype=object),
#  array(['2019-02-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-18', list([1, 0, 1, 4])], dtype=object),
#  array(['2019-02-19', list([1, 0, 1, 1])], dtype=object),
#  array(['2019-02-20', list([1, 0, 1, 3])], dtype=object),
#  array(['2019-02-21', list([1, 1, 1, 1])], dtype=object),
#  array(['2019-02-22', list([1, 0, 1, 1])], dtype=object),
#  array(['2019-02-23', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-25', list([1, 0, 1, 1])], dtype=object),
#  array(['2019-02-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-02-27', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-02-28', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-01', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-03-02', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-03', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-03-04', list([1, 0, 1, 11])], dtype=object),
#  array(['2019-03-05', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-06', list([0, 0, 0, 3])], dtype=object),
#  array(['2019-03-07', list([0, 0, 0, 5])], dtype=object),
#  array(['2019-03-08', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-09', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-10', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-11', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-12', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-03-13', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-14', list([0, 0, 0, 2])], dtype=object),
#  array(['2019-03-15', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-16', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-17', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-18', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-03-19', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-03-20', list([0, 0, 0, 2])], dtype=object),
#  array(['2019-03-21', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-22', list([0, 0, 0, 1])], dtype=object),
#  array(['2019-03-23', list([0, 0, 0, 3])], dtype=object),
#  array(['2019-03-24', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-25', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-26', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-27', list([0, 0, 0, 0])], dtype=object),
#  array(['2019-03-28', list([0, 0, 0, 0])], dtype=object),
#  ...]
